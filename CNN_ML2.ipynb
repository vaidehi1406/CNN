# %%
import keras
import keras.utils
from keras import utils as np_utils
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten

from sklearn.metrics import accuracy_score

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")

# %%
X_train = X_train/255
X_test = X_test/255

# %%
n_classes = 10
print("Shape before one_hot encoding: ",y_train.shape)
Y_train = np_utils.to_categorical(y_train, n_classes)
Y_test = np_utils.to_categorical(y_test, n_classes)
print("Shape after one_hot encoding: ",Y_train.shape)
# Out:
# Shape before one_hot encoding:  (60000,)
# Shape after one_hot encoding:  (60000, 10)

# %%
model = Sequential()

model.add(Conv2D(25, kernel_size=(3,3), strides=(1,1), padding="valid", activation="relu", input_shape=(28,28,1)))
model.add(MaxPool2D(pool_size=(1,1)))

model.add(Flatten())

model.add(Dense(100, activation="relu"))

model.add(Dense(10, activation="softmax"))

# %%
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer="adam")
model.fit(X_train, Y_train, batch_size=128, epochs=10, validation_data=(X_test,Y_test))
# Out:
# Epoch 1/10
# 469/469 [==============================] - 52s 109ms/step - loss: 0.2047 - accuracy: 0.9398 - val_loss: 0.0908 - val_accuracy: 0.9725
# Epoch 2/10
# 469/469 [==============================] - 53s 113ms/step - loss: 0.0622 - accuracy: 0.9812 - val_loss: 0.0653 - val_accuracy: 0.9797
# Epoch 3/10
# 469/469 [==============================] - 51s 108ms/step - loss: 0.0361 - accuracy: 0.9894 - val_loss: 0.0527 - val_accuracy: 0.9826
# Epoch 4/10
# 469/469 [==============================] - 52s 110ms/step - loss: 0.0219 - accuracy: 0.9937 - val_loss: 0.0525 - val_accuracy: 0.9825
# Epoch 5/10
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0136 - accuracy: 0.9962 - val_loss: 0.0518 - val_accuracy: 0.9832
# Epoch 6/10
# 469/469 [==============================] - 50s 106ms/step - loss: 0.0114 - accuracy: 0.9965 - val_loss: 0.0580 - val_accuracy: 0.9831
# Epoch 7/10
# 469/469 [==============================] - 51s 108ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.0583 - val_accuracy: 0.9833
# Epoch 8/10
# 469/469 [==============================] - 50s 107ms/step - loss: 0.0055 - accuracy: 0.9985 - val_loss: 0.0730 - val_accuracy: 0.9804
# Epoch 9/10
# 469/469 [==============================] - 51s 108ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0703 - val_accuracy: 0.9804
# Epoch 10/10
# 469/469 [==============================] - 51s 108ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.0630 - val_accuracy: 0.9835
